# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy



# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#This is very similar to 06-Python-APIs2Activities05-Ins_OpenWeatherDataFrameSolved
from api_keys import api_key

# OpenWeatherMap API Key
api_key = api_keys.api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}"
    #&units={units}&q="

city_info = []
record_count = 0



for city in cities:
     
    city_url = query_url + "&q=" + city
    print("Beginning Data Retrieval")
    print("------------------------")
    record_count += 1
    print(f"Processing Record {record_count}|{city}") 
    
    try:

        city_weather = requests.get(city_url).json()
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]      
        city_date = city_weather["dt"]      
        city_humidity = city_weather["main"]["humidity"]      
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_wind = city_weather["wind"]["speed"]
        
        city_info.append({"City": city,"Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp,                   "Humidity": city_humidity,
                    "Cloudiness": city_clouds,"Wind Speed": city_wind,"Country": city_country,
                    "Date": city_date})

    except:
        print("City has been obiliterated by aliens. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-------------------------")
print("Data Retrieval Complete ")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1|attawapiskat
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 2|illoqqortoormiut
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 3|iqaluit
# Beginning Data Retrieval
# ------------------------
# Processing Record 4|taolanaro
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 5|hobart
# Beginning Data Retrieval
# ------------------------
# Processing Record 6|port alfred
# Beginning Data Retrieval
# ------------------------
# Processing Record 7|richards bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 8|punta arenas
# Beginning Data Retrieval
# ------------------------
# Processing Record 9|rikitea
# Beginning Data Retrieval
# ------------------------
# Processing Record 10|kapaa
# Beginning Data Retrieval
# ------------------------
# Processing Record 11|touros
# Beginning Data Retrieval
# ------------------------
# Processing Record 12|cape town
# Beginning Data Retrieval
# ------------------------
# Processing Record 13|east london
# Beginning Data Retrieval
# ------------------------
# Processing Record 14|constitucion
# Beginning Data Retrieval
# ------------------------
# Processing Record 15|magadan
# Beginning Data Retrieval
# ------------------------
# Processing Record 16|albany
# Beginning Data Retrieval
# ------------------------
# Processing Record 17|algarrobo
# Beginning Data Retrieval
# ------------------------
# Processing Record 18|havoysund
# Beginning Data Retrieval
# ------------------------
# Processing Record 19|butaritari
# Beginning Data Retrieval
# ------------------------
# Processing Record 20|sioux lookout
# Beginning Data Retrieval
# ------------------------
# Processing Record 21|chokurdakh
# Beginning Data Retrieval
# ------------------------
# Processing Record 22|bethel
# Beginning Data Retrieval
# ------------------------
# Processing Record 23|mehamn
# Beginning Data Retrieval
# ------------------------
# Processing Record 24|vrangel
# Beginning Data Retrieval
# ------------------------
# Processing Record 25|new norfolk
# Beginning Data Retrieval
# ------------------------
# Processing Record 26|itarema
# Beginning Data Retrieval
# ------------------------
# Processing Record 27|atuona
# Beginning Data Retrieval
# ------------------------
# Processing Record 28|paamiut
# Beginning Data Retrieval
# ------------------------
# Processing Record 29|tuktoyaktuk
# Beginning Data Retrieval
# ------------------------
# Processing Record 30|viedma
# Beginning Data Retrieval
# ------------------------
# Processing Record 31|songkhla
# Beginning Data Retrieval
# ------------------------
# Processing Record 32|ishigaki
# Beginning Data Retrieval
# ------------------------
# Processing Record 33|bluff
# Beginning Data Retrieval
# ------------------------
# Processing Record 34|vaini
# Beginning Data Retrieval
# ------------------------
# Processing Record 35|aljezur
# Beginning Data Retrieval
# ------------------------
# Processing Record 36|castro
# Beginning Data Retrieval
# ------------------------
# Processing Record 37|sola
# Beginning Data Retrieval
# ------------------------
# Processing Record 38|hermanus
# Beginning Data Retrieval
# ------------------------
# Processing Record 39|mataura
# Beginning Data Retrieval
# ------------------------
# Processing Record 40|hornepayne
# Beginning Data Retrieval
# ------------------------
# Processing Record 41|barrow
# Beginning Data Retrieval
# ------------------------
# Processing Record 42|kursenai
# Beginning Data Retrieval
# ------------------------
# Processing Record 43|luderitz
# Beginning Data Retrieval
# ------------------------
# Processing Record 44|padang
# Beginning Data Retrieval
# ------------------------
# Processing Record 45|puerto escondido
# Beginning Data Retrieval
# ------------------------
# Processing Record 46|marcona
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 47|mount isa
# Beginning Data Retrieval
# ------------------------
# Processing Record 48|nusaybin
# Beginning Data Retrieval
# ------------------------
# Processing Record 49|jamestown
# Beginning Data Retrieval
# ------------------------
# Processing Record 50|ponta do sol
# Beginning Data Retrieval
# ------------------------
# Processing Record 51|belushya guba
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 52|barentsburg
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 53|busselton
# Beginning Data Retrieval
# ------------------------
# Processing Record 54|luanda
# Beginning Data Retrieval
# ------------------------
# Processing Record 55|nicoya
# Beginning Data Retrieval
# ------------------------
# Processing Record 56|banepa
# Beginning Data Retrieval
# ------------------------
# Processing Record 57|jyvaskyla
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 58|makung
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 59|codrington
# Beginning Data Retrieval
# ------------------------
# Processing Record 60|ushuaia
# Beginning Data Retrieval
# ------------------------
# Processing Record 61|dikson
# Beginning Data Retrieval
# ------------------------
# Processing Record 62|tasiilaq
# Beginning Data Retrieval
# ------------------------
# Processing Record 63|geraldton
# Beginning Data Retrieval
# ------------------------
# Processing Record 64|paso del macho
# Beginning Data Retrieval
# ------------------------
# Processing Record 65|saint-philippe
# Beginning Data Retrieval
# ------------------------
# Processing Record 66|puerto ayora
# Beginning Data Retrieval
# ------------------------
# Processing Record 67|alexandria
# Beginning Data Retrieval
# ------------------------
# Processing Record 68|ostrovnoy
# Beginning Data Retrieval
# ------------------------
# Processing Record 69|katsuura
# Beginning Data Retrieval
# ------------------------
# Processing Record 70|hay river
# Beginning Data Retrieval
# ------------------------
# Processing Record 71|thompson
# Beginning Data Retrieval
# ------------------------
# Processing Record 72|bredasdorp
# Beginning Data Retrieval
# ------------------------
# Processing Record 73|kodiak
# Beginning Data Retrieval
# ------------------------
# Processing Record 74|vila velha
# Beginning Data Retrieval
# ------------------------
# Processing Record 75|eloy
# Beginning Data Retrieval
# ------------------------
# Processing Record 76|port elizabeth
# Beginning Data Retrieval
# ------------------------
# Processing Record 77|lebu
# Beginning Data Retrieval
# ------------------------
# Processing Record 78|zlobin
# Beginning Data Retrieval
# ------------------------
# Processing Record 79|alofi
# Beginning Data Retrieval
# ------------------------
# Processing Record 80|esperance
# Beginning Data Retrieval
# ------------------------
# Processing Record 81|sokolo
# Beginning Data Retrieval
# ------------------------
# Processing Record 82|tiksi
# Beginning Data Retrieval
# ------------------------
# Processing Record 83|longyearbyen
# Beginning Data Retrieval
# ------------------------
# Processing Record 84|altay
# Beginning Data Retrieval
# ------------------------
# Processing Record 85|san policarpo
# Beginning Data Retrieval
# ------------------------
# Processing Record 86|ixtapa
# Beginning Data Retrieval
# ------------------------
# Processing Record 87|norman wells
# Beginning Data Retrieval
# ------------------------
# Processing Record 88|cockburn town
# Beginning Data Retrieval
# ------------------------
# Processing Record 89|port hedland
# Beginning Data Retrieval
# ------------------------
# Processing Record 90|ygatimi
# Beginning Data Retrieval
# ------------------------
# Processing Record 91|mitsamiouli
# Beginning Data Retrieval
# ------------------------
# Processing Record 92|haines junction
# Beginning Data Retrieval
# ------------------------
# Processing Record 93|clyde river
# Beginning Data Retrieval
# ------------------------
# Processing Record 94|duverge
# Beginning Data Retrieval
# ------------------------
# Processing Record 95|nikki
# Beginning Data Retrieval
# ------------------------
# Processing Record 96|mao
# Beginning Data Retrieval
# ------------------------
# Processing Record 97|klyuchi
# Beginning Data Retrieval
# ------------------------
# Processing Record 98|porto velho
# Beginning Data Retrieval
# ------------------------
# Processing Record 99|henties bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 100|upernavik
# Beginning Data Retrieval
# ------------------------
# Processing Record 101|kailua
# Beginning Data Retrieval
# ------------------------
# Processing Record 102|saleaula
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 103|tsihombe
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 104|saldanha
# Beginning Data Retrieval
# ------------------------
# Processing Record 105|terrak
# Beginning Data Retrieval
# ------------------------
# Processing Record 106|agadez
# Beginning Data Retrieval
# ------------------------
# Processing Record 107|los llanos de aridane
# Beginning Data Retrieval
# ------------------------
# Processing Record 108|bubaque
# Beginning Data Retrieval
# ------------------------
# Processing Record 109|nizhneyansk
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 110|grindavik
# Beginning Data Retrieval
# ------------------------
# Processing Record 111|coihaique
# Beginning Data Retrieval
# ------------------------
# Processing Record 112|morwell
# Beginning Data Retrieval
# ------------------------
# Processing Record 113|broken hill
# Beginning Data Retrieval
# ------------------------
# Processing Record 114|surt
# Beginning Data Retrieval
# ------------------------
# Processing Record 115|mar del plata
# Beginning Data Retrieval
# ------------------------
# Processing Record 116|doctor pedro p. pena
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 117|kenai
# Beginning Data Retrieval
# ------------------------
# Processing Record 118|quballat
# Beginning Data Retrieval
# ------------------------
# Processing Record 119|nechi
# Beginning Data Retrieval
# ------------------------
# Processing Record 120|taltal
# Beginning Data Retrieval
# ------------------------
# Processing Record 121|talnakh
# Beginning Data Retrieval
# ------------------------
# Processing Record 122|hilo
# Beginning Data Retrieval
# ------------------------
# Processing Record 123|ribeira grande
# Beginning Data Retrieval
# ------------------------
# Processing Record 124|halifax
# Beginning Data Retrieval
# ------------------------
# Processing Record 125|tual
# Beginning Data Retrieval
# ------------------------
# Processing Record 126|iisalmi
# Beginning Data Retrieval
# ------------------------
# Processing Record 127|pauini
# Beginning Data Retrieval
# ------------------------
# Processing Record 128|noumea
# Beginning Data Retrieval
# ------------------------
# Processing Record 129|arlit
# Beginning Data Retrieval
# ------------------------
# Processing Record 130|ancud
# Beginning Data Retrieval
# ------------------------
# Processing Record 131|port hardy
# Beginning Data Retrieval
# ------------------------
# Processing Record 132|luwingu
# Beginning Data Retrieval
# ------------------------
# Processing Record 133|hamilton
# Beginning Data Retrieval
# ------------------------
# Processing Record 134|waipawa
# Beginning Data Retrieval
# ------------------------
# Processing Record 135|filadelfia
# Beginning Data Retrieval
# ------------------------
# Processing Record 136|victor harbor
# Beginning Data Retrieval
# ------------------------
# Processing Record 137|high level
# Beginning Data Retrieval
# ------------------------
# Processing Record 138|vryheid
# Beginning Data Retrieval
# ------------------------
# Processing Record 139|faya
# Beginning Data Retrieval
# ------------------------
# Processing Record 140|tigil
# Beginning Data Retrieval
# ------------------------
# Processing Record 141|formoso do araguaia
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 142|soyo
# Beginning Data Retrieval
# ------------------------
# Processing Record 143|smithers
# Beginning Data Retrieval
# ------------------------
# Processing Record 144|cidreira
# Beginning Data Retrieval
# ------------------------
# Processing Record 145|sitka
# Beginning Data Retrieval
# ------------------------
# Processing Record 146|narsaq
# Beginning Data Retrieval
# ------------------------
# Processing Record 147|cayenne
# Beginning Data Retrieval
# ------------------------
# Processing Record 148|mackenzie
# Beginning Data Retrieval
# ------------------------
# Processing Record 149|point pedro
# Beginning Data Retrieval
# ------------------------
# Processing Record 150|talara
# Beginning Data Retrieval
# ------------------------
# Processing Record 151|hasaki
# Beginning Data Retrieval
# ------------------------
# Processing Record 152|vao
# Beginning Data Retrieval
# ------------------------
# Processing Record 153|oldenburg
# Beginning Data Retrieval
# ------------------------
# Processing Record 154|nanortalik
# Beginning Data Retrieval
# ------------------------
# Processing Record 155|shangzhi
# Beginning Data Retrieval
# ------------------------
# Processing Record 156|galle
# Beginning Data Retrieval
# ------------------------
# Processing Record 157|komsomolskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 158|arraial do cabo
# Beginning Data Retrieval
# ------------------------
# Processing Record 159|erenhot
# Beginning Data Retrieval
# ------------------------
# Processing Record 160|rio cuarto
# Beginning Data Retrieval
# ------------------------
# Processing Record 161|san patricio
# Beginning Data Retrieval
# ------------------------
# Processing Record 162|palmer
# Beginning Data Retrieval
# ------------------------
# Processing Record 163|bodoco
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 164|faanui
# Beginning Data Retrieval
# ------------------------
# Processing Record 165|laishevo
# Beginning Data Retrieval
# ------------------------
# Processing Record 166|zemio
# Beginning Data Retrieval
# ------------------------
# Processing Record 167|saint-georges
# Beginning Data Retrieval
# ------------------------
# Processing Record 168|deputatskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 169|kalundborg
# Beginning Data Retrieval
# ------------------------
# Processing Record 170|mys shmidta
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 171|kampot
# Beginning Data Retrieval
# ------------------------
# Processing Record 172|tocopilla
# Beginning Data Retrieval
# ------------------------
# Processing Record 173|yulara
# Beginning Data Retrieval
# ------------------------
# Processing Record 174|bengkulu
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 175|pangnirtung
# Beginning Data Retrieval
# ------------------------
# Processing Record 176|kaitangata
# Beginning Data Retrieval
# ------------------------
# Processing Record 177|grand gaube
# Beginning Data Retrieval
# ------------------------
# Processing Record 178|awjilah
# Beginning Data Retrieval
# ------------------------
# Processing Record 179|vitim
# Beginning Data Retrieval
# ------------------------
# Processing Record 180|pevek
# Beginning Data Retrieval
# ------------------------
# Processing Record 181|yumen
# Beginning Data Retrieval
# ------------------------
# Processing Record 182|isangel
# Beginning Data Retrieval
# ------------------------
# Processing Record 183|bur gabo
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 184|huaraz
# Beginning Data Retrieval
# ------------------------
# Processing Record 185|tabuk
# Beginning Data Retrieval
# ------------------------
# Processing Record 186|pakwach
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 187|masterton
# Beginning Data Retrieval
# ------------------------
# Processing Record 188|buchanan
# Beginning Data Retrieval
# ------------------------
# Processing Record 189|goderich
# Beginning Data Retrieval
# ------------------------
# Processing Record 190|puerto cabezas
# Beginning Data Retrieval
# ------------------------
# Processing Record 191|airai
# Beginning Data Retrieval
# ------------------------
# Processing Record 192|banjar
# Beginning Data Retrieval
# ------------------------
# Processing Record 193|pitimbu
# Beginning Data Retrieval
# ------------------------
# Processing Record 194|pangai
# Beginning Data Retrieval
# ------------------------
# Processing Record 195|yola
# Beginning Data Retrieval
# ------------------------
# Processing Record 196|ilulissat
# Beginning Data Retrieval
# ------------------------
# Processing Record 197|huarmey
# Beginning Data Retrieval
# ------------------------
# Processing Record 198|qandahar
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 199|qaanaaq
# Beginning Data Retrieval
# ------------------------
# Processing Record 200|xiangxiang
# Beginning Data Retrieval
# ------------------------
# Processing Record 201|barranco
# Beginning Data Retrieval
# ------------------------
# Processing Record 202|isla mujeres
# Beginning Data Retrieval
# ------------------------
# Processing Record 203|vila franca do campo
# Beginning Data Retrieval
# ------------------------
# Processing Record 204|port moresby
# Beginning Data Retrieval
# ------------------------
# Processing Record 205|poum
# Beginning Data Retrieval
# ------------------------
# Processing Record 206|mount gambier
# Beginning Data Retrieval
# ------------------------
# Processing Record 207|gizo
# Beginning Data Retrieval
# ------------------------
# Processing Record 208|charleston
# Beginning Data Retrieval
# ------------------------
# Processing Record 209|lifford
# Beginning Data Retrieval
# ------------------------
# Processing Record 210|kuche
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 211|muskegon
# Beginning Data Retrieval
# ------------------------
# Processing Record 212|klaksvik
# Beginning Data Retrieval
# ------------------------
# Processing Record 213|necochea
# Beginning Data Retrieval
# ------------------------
# Processing Record 214|ambon
# Beginning Data Retrieval
# ------------------------
# Processing Record 215|akonolinga
# Beginning Data Retrieval
# ------------------------
# Processing Record 216|mahibadhoo
# Beginning Data Retrieval
# ------------------------
# Processing Record 217|vestmanna
# Beginning Data Retrieval
# ------------------------
# Processing Record 218|umzimvubu
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 219|gurgan
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 220|biak
# Beginning Data Retrieval
# ------------------------
# Processing Record 221|denpasar
# Beginning Data Retrieval
# ------------------------
# Processing Record 222|tiznit
# Beginning Data Retrieval
# ------------------------
# Processing Record 223|bereda
# Beginning Data Retrieval
# ------------------------
# Processing Record 224|diego de almagro
# Beginning Data Retrieval
# ------------------------
# Processing Record 225|praia da vitoria
# Beginning Data Retrieval
# ------------------------
# Processing Record 226|pecos
# Beginning Data Retrieval
# ------------------------
# Processing Record 227|roald
# Beginning Data Retrieval
# ------------------------
# Processing Record 228|georgetown
# Beginning Data Retrieval
# ------------------------
# Processing Record 229|saskylakh
# Beginning Data Retrieval
# ------------------------
# Processing Record 230|avarua
# Beginning Data Retrieval
# ------------------------
# Processing Record 231|lavrentiya
# Beginning Data Retrieval
# ------------------------
# Processing Record 232|havelock
# Beginning Data Retrieval
# ------------------------
# Processing Record 233|ilebo
# Beginning Data Retrieval
# ------------------------
# Processing Record 234|bowen
# Beginning Data Retrieval
# ------------------------
# Processing Record 235|homburg
# Beginning Data Retrieval
# ------------------------
# Processing Record 236|madison heights
# Beginning Data Retrieval
# ------------------------
# Processing Record 237|nouadhibou
# Beginning Data Retrieval
# ------------------------
# Processing Record 238|nisia floresta
# Beginning Data Retrieval
# ------------------------
# Processing Record 239|grand river south east
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 240|sarangani
# Beginning Data Retrieval
# ------------------------
# Processing Record 241|saint-leu
# Beginning Data Retrieval
# ------------------------
# Processing Record 242|nsanje
# Beginning Data Retrieval
# ------------------------
# Processing Record 243|ekuvukeni
# Beginning Data Retrieval
# ------------------------
# Processing Record 244|brae
# Beginning Data Retrieval
# ------------------------
# Processing Record 245|carnarvon
# Beginning Data Retrieval
# ------------------------
# Processing Record 246|bambous virieux
# Beginning Data Retrieval
# ------------------------
# Processing Record 247|kruisfontein
# Beginning Data Retrieval
# ------------------------
# Processing Record 248|pastavy
# Beginning Data Retrieval
# ------------------------
# Processing Record 249|makakilo city
# Beginning Data Retrieval
# ------------------------
# Processing Record 250|kirakira
# Beginning Data Retrieval
# ------------------------
# Processing Record 251|nueva loja
# Beginning Data Retrieval
# ------------------------
# Processing Record 252|chuy
# Beginning Data Retrieval
# ------------------------
# Processing Record 253|puerto del rosario
# Beginning Data Retrieval
# ------------------------
# Processing Record 254|agucadoura
# Beginning Data Retrieval
# ------------------------
# Processing Record 255|mwinilunga
# Beginning Data Retrieval
# ------------------------
# Processing Record 256|eyl
# Beginning Data Retrieval
# ------------------------
# Processing Record 257|tessalit
# Beginning Data Retrieval
# ------------------------
# Processing Record 258|pozo colorado
# Beginning Data Retrieval
# ------------------------
# Processing Record 259|krasnoarmeysk
# Beginning Data Retrieval
# ------------------------
# Processing Record 260|hithadhoo
# Beginning Data Retrieval
# ------------------------
# Processing Record 261|yellowknife
# Beginning Data Retrieval
# ------------------------
# Processing Record 262|denham springs
# Beginning Data Retrieval
# ------------------------
# Processing Record 263|flinders
# Beginning Data Retrieval
# ------------------------
# Processing Record 264|buraydah
# Beginning Data Retrieval
# ------------------------
# Processing Record 265|sao filipe
# Beginning Data Retrieval
# ------------------------
# Processing Record 266|fershampenuaz
# Beginning Data Retrieval
# ------------------------
# Processing Record 267|roma
# Beginning Data Retrieval
# ------------------------
# Processing Record 268|kamenka
# Beginning Data Retrieval
# ------------------------
# Processing Record 269|kijang
# Beginning Data Retrieval
# ------------------------
# Processing Record 270|ukiah
# Beginning Data Retrieval
# ------------------------
# Processing Record 271|acajutla
# Beginning Data Retrieval
# ------------------------
# Processing Record 272|gravelbourg
# Beginning Data Retrieval
# ------------------------
# Processing Record 273|outlook
# Beginning Data Retrieval
# ------------------------
# Processing Record 274|westport
# Beginning Data Retrieval
# ------------------------
# Processing Record 275|guapimirim
# Beginning Data Retrieval
# ------------------------
# Processing Record 276|sentyabrskiy
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 277|dubti
# Beginning Data Retrieval
# ------------------------
# Processing Record 278|myitkyina
# Beginning Data Retrieval
# ------------------------
# Processing Record 279|jurado
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 280|pantai remis
# Beginning Data Retrieval
# ------------------------
# Processing Record 281|almaznyy
# Beginning Data Retrieval
# ------------------------
# Processing Record 282|ambilobe
# Beginning Data Retrieval
# ------------------------
# Processing Record 283|port lincoln
# Beginning Data Retrieval
# ------------------------
# Processing Record 284|ulaanbaatar
# Beginning Data Retrieval
# ------------------------
# Processing Record 285|lufilufi
# Beginning Data Retrieval
# ------------------------
# Processing Record 286|severo-kurilsk
# Beginning Data Retrieval
# ------------------------
# Processing Record 287|soe
# Beginning Data Retrieval
# ------------------------
# Processing Record 288|pokhara
# Beginning Data Retrieval
# ------------------------
# Processing Record 289|marsh harbour
# Beginning Data Retrieval
# ------------------------
# Processing Record 290|otkaznoye
# Beginning Data Retrieval
# ------------------------
# Processing Record 291|ewa beach
# Beginning Data Retrieval
# ------------------------
# Processing Record 292|ust-kut
# Beginning Data Retrieval
# ------------------------
# Processing Record 293|santa luzia
# Beginning Data Retrieval
# ------------------------
# Processing Record 294|berdigestyakh
# Beginning Data Retrieval
# ------------------------
# Processing Record 295|thunder bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 296|doctor phillips
# Beginning Data Retrieval
# ------------------------
# Processing Record 297|beringovskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 298|zyryanka
# Beginning Data Retrieval
# ------------------------
# Processing Record 299|lithgow
# Beginning Data Retrieval
# ------------------------
# Processing Record 300|alta floresta
# Beginning Data Retrieval
# ------------------------
# Processing Record 301|hofn
# Beginning Data Retrieval
# ------------------------
# Processing Record 302|honningsvag
# Beginning Data Retrieval
# ------------------------
# Processing Record 303|saint-pierre
# Beginning Data Retrieval
# ------------------------
# Processing Record 304|caravelas
# Beginning Data Retrieval
# ------------------------
# Processing Record 305|cabo san lucas
# Beginning Data Retrieval
# ------------------------
# Processing Record 306|sorong
# Beginning Data Retrieval
# ------------------------
# Processing Record 307|lahad datu
# Beginning Data Retrieval
# ------------------------
# Processing Record 308|san pedro de macoris
# Beginning Data Retrieval
# ------------------------
# Processing Record 309|souillac
# Beginning Data Retrieval
# ------------------------
# Processing Record 310|katha
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 311|santa maria del oro
# Beginning Data Retrieval
# ------------------------
# Processing Record 312|bafq
# Beginning Data Retrieval
# ------------------------
# Processing Record 313|chapais
# Beginning Data Retrieval
# ------------------------
# Processing Record 314|maarianhamina
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 315|monrovia
# Beginning Data Retrieval
# ------------------------
# Processing Record 316|seoul
# Beginning Data Retrieval
# ------------------------
# Processing Record 317|louisbourg
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 318|birjand
# Beginning Data Retrieval
# ------------------------
# Processing Record 319|coquimbo
# Beginning Data Retrieval
# ------------------------
# Processing Record 320|kadykchan
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 321|svetlyy
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 322|stephenville crossing
# Beginning Data Retrieval
# ------------------------
# Processing Record 323|ulaangom
# Beginning Data Retrieval
# ------------------------
# Processing Record 324|marzuq
# Beginning Data Retrieval
# ------------------------
# Processing Record 325|elsterwerda
# Beginning Data Retrieval
# ------------------------
# Processing Record 326|salalah
# Beginning Data Retrieval
# ------------------------
# Processing Record 327|finschhafen
# Beginning Data Retrieval
# ------------------------
# Processing Record 328|la ronge
# Beginning Data Retrieval
# ------------------------
# Processing Record 329|kendari
# Beginning Data Retrieval
# ------------------------
# Processing Record 330|cherskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 331|esmeraldas
# Beginning Data Retrieval
# ------------------------
# Processing Record 332|port macquarie
# Beginning Data Retrieval
# ------------------------
# Processing Record 333|half moon bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 334|machilipatnam
# Beginning Data Retrieval
# ------------------------
# Processing Record 335|rathdrum
# Beginning Data Retrieval
# ------------------------
# Processing Record 336|mahebourg
# Beginning Data Retrieval
# ------------------------
# Processing Record 337|tukrah
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 338|kathu
# Beginning Data Retrieval
# ------------------------
# Processing Record 339|zhuhai
# Beginning Data Retrieval
# ------------------------
# Processing Record 340|eregli
# Beginning Data Retrieval
# ------------------------
# Processing Record 341|rolim de moura
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 342|naze
# Beginning Data Retrieval
# ------------------------
# Processing Record 343|karamea
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 344|teahupoo
# Beginning Data Retrieval
# ------------------------
# Processing Record 345|te anau
# Beginning Data Retrieval
# ------------------------
# Processing Record 346|sept-iles
# Beginning Data Retrieval
# ------------------------
# Processing Record 347|strezhevoy
# Beginning Data Retrieval
# ------------------------
# Processing Record 348|anadyr
# Beginning Data Retrieval
# ------------------------
# Processing Record 349|marovoay
# Beginning Data Retrieval
# ------------------------
# Processing Record 350|tautira
# Beginning Data Retrieval
# ------------------------
# Processing Record 351|ahipara
# Beginning Data Retrieval
# ------------------------
# Processing Record 352|nicolas bravo
# Beginning Data Retrieval
# ------------------------
# Processing Record 353|provideniya
# Beginning Data Retrieval
# ------------------------
# Processing Record 354|formosa do rio preto
# Beginning Data Retrieval
# ------------------------
# Processing Record 355|meulaboh
# Beginning Data Retrieval
# ------------------------
# Processing Record 356|quatre cocos
# Beginning Data Retrieval
# ------------------------
# Processing Record 357|pisa
# Beginning Data Retrieval
# ------------------------
# Processing Record 358|hinatuan
# Beginning Data Retrieval
# ------------------------
# Processing Record 359|voh
# Beginning Data Retrieval
# ------------------------
# Processing Record 360|morogoro
# Beginning Data Retrieval
# ------------------------
# Processing Record 361|suao
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 362|yanam
# Beginning Data Retrieval
# ------------------------
# Processing Record 363|xinzhou
# Beginning Data Retrieval
# ------------------------
# Processing Record 364|payakumbuh
# Beginning Data Retrieval
# ------------------------
# Processing Record 365|the pas
# Beginning Data Retrieval
# ------------------------
# Processing Record 366|verkhnevilyuysk
# Beginning Data Retrieval
# ------------------------
# Processing Record 367|konevo
# Beginning Data Retrieval
# ------------------------
# Processing Record 368|qinhuangdao
# Beginning Data Retrieval
# ------------------------
# Processing Record 369|ozu
# Beginning Data Retrieval
# ------------------------
# Processing Record 370|qasigiannguit
# Beginning Data Retrieval
# ------------------------
# Processing Record 371|dhidhdhoo
# Beginning Data Retrieval
# ------------------------
# Processing Record 372|biga
# Beginning Data Retrieval
# ------------------------
# Processing Record 373|omboue
# Beginning Data Retrieval
# ------------------------
# Processing Record 374|rock sound
# Beginning Data Retrieval
# ------------------------
# Processing Record 375|acara
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 376|baker city
# Beginning Data Retrieval
# ------------------------
# Processing Record 377|tuatapere
# Beginning Data Retrieval
# ------------------------
# Processing Record 378|rocha
# Beginning Data Retrieval
# ------------------------
# Processing Record 379|kieta
# Beginning Data Retrieval
# ------------------------
# Processing Record 380|hami
# Beginning Data Retrieval
# ------------------------
# Processing Record 381|nome
# Beginning Data Retrieval
# ------------------------
# Processing Record 382|lasa
# Beginning Data Retrieval
# ------------------------
# Processing Record 383|khatanga
# Beginning Data Retrieval
# ------------------------
# Processing Record 384|mogadishu
# Beginning Data Retrieval
# ------------------------
# Processing Record 385|maridi
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 386|itatskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 387|bardiyah
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 388|trzebiatow
# Beginning Data Retrieval
# ------------------------
# Processing Record 389|dunda
# Beginning Data Retrieval
# ------------------------
# Processing Record 390|thinadhoo
# Beginning Data Retrieval
# ------------------------
# Processing Record 391|khani
# Beginning Data Retrieval
# ------------------------
# Processing Record 392|ust-shonosha
# Beginning Data Retrieval
# ------------------------
# Processing Record 393|bambamarca
# Beginning Data Retrieval
# ------------------------
# Processing Record 394|margate
# Beginning Data Retrieval
# ------------------------
# Processing Record 395|garden city
# Beginning Data Retrieval
# ------------------------
# Processing Record 396|alyangula
# Beginning Data Retrieval
# ------------------------
# Processing Record 397|simi
# Beginning Data Retrieval
# ------------------------
# Processing Record 398|tayu
# Beginning Data Retrieval
# ------------------------
# Processing Record 399|aktas
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 400|bermeo
# Beginning Data Retrieval
# ------------------------
# Processing Record 401|sharjah
# Beginning Data Retrieval
# ------------------------
# Processing Record 402|micheweni
# Beginning Data Retrieval
# ------------------------
# Processing Record 403|lima
# Beginning Data Retrieval
# ------------------------
# Processing Record 404|victoria
# Beginning Data Retrieval
# ------------------------
# Processing Record 405|nipawin
# Beginning Data Retrieval
# ------------------------
# Processing Record 406|tura
# Beginning Data Retrieval
# ------------------------
# Processing Record 407|nylstroom
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 408|kulachi
# Beginning Data Retrieval
# ------------------------
# Processing Record 409|saint george
# Beginning Data Retrieval
# ------------------------
# Processing Record 410|kichmengskiy gorodok
# Beginning Data Retrieval
# ------------------------
# Processing Record 411|axim
# Beginning Data Retrieval
# ------------------------
# Processing Record 412|rawson
# Beginning Data Retrieval
# ------------------------
# Processing Record 413|lompoc
# Beginning Data Retrieval
# ------------------------
# Processing Record 414|copiapo
# Beginning Data Retrieval
# ------------------------
# Processing Record 415|dhar
# Beginning Data Retrieval
# ------------------------
# Processing Record 416|shingu
# Beginning Data Retrieval
# ------------------------
# Processing Record 417|rincon
# Beginning Data Retrieval
# ------------------------
# Processing Record 418|kununurra
# Beginning Data Retrieval
# ------------------------
# Processing Record 419|dubenskiy
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 420|northam
# Beginning Data Retrieval
# ------------------------
# Processing Record 421|fortuna
# Beginning Data Retrieval
# ------------------------
# Processing Record 422|puerto princesa
# Beginning Data Retrieval
# ------------------------
# Processing Record 423|port blair
# Beginning Data Retrieval
# ------------------------
# Processing Record 424|glendive
# Beginning Data Retrieval
# ------------------------
# Processing Record 425|tucuman
# Beginning Data Retrieval
# ------------------------
# Processing Record 426|kahului
# Beginning Data Retrieval
# ------------------------
# Processing Record 427|nhamunda
# Beginning Data Retrieval
# ------------------------
# Processing Record 428|arandis
# Beginning Data Retrieval
# ------------------------
# Processing Record 429|ocotal
# Beginning Data Retrieval
# ------------------------
# Processing Record 430|dawlatabad
# Beginning Data Retrieval
# ------------------------
# Processing Record 431|acapulco
# Beginning Data Retrieval
# ------------------------
# Processing Record 432|dunedin
# Beginning Data Retrieval
# ------------------------
# Processing Record 433|aklavik
# Beginning Data Retrieval
# ------------------------
# Processing Record 434|maningrida
# Beginning Data Retrieval
# ------------------------
# Processing Record 435|gravdal
# Beginning Data Retrieval
# ------------------------
# Processing Record 436|sorland
# Beginning Data Retrieval
# ------------------------
# Processing Record 437|bolungarvik
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 438|kinsale
# Beginning Data Retrieval
# ------------------------
# Processing Record 439|tuggurt
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 440|halalo
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 441|saryshagan
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 442|aktash
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 443|upington
# Beginning Data Retrieval
# ------------------------
# Processing Record 444|sisimiut
# Beginning Data Retrieval
# ------------------------
# Processing Record 445|ransang
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 446|basoko
# Beginning Data Retrieval
# ------------------------
# Processing Record 447|qingan
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 448|tolaga bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 449|mumford
# Beginning Data Retrieval
# ------------------------
# Processing Record 450|amderma
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 451|sydney
# Beginning Data Retrieval
# ------------------------
# Processing Record 452|kavieng
# Beginning Data Retrieval
# ------------------------
# Processing Record 453|manaus
# Beginning Data Retrieval
# ------------------------
# Processing Record 454|baykit
# Beginning Data Retrieval
# ------------------------
# Processing Record 455|yakymivka
# Beginning Data Retrieval
# ------------------------
# Processing Record 456|snezhnogorsk
# Beginning Data Retrieval
# ------------------------
# Processing Record 457|san cristobal
# Beginning Data Retrieval
# ------------------------
# Processing Record 458|talakan
# Beginning Data Retrieval
# ------------------------
# Processing Record 459|swabi
# Beginning Data Retrieval
# ------------------------
# Processing Record 460|ocos
# Beginning Data Retrieval
# ------------------------
# Processing Record 461|pringsewu
# Beginning Data Retrieval
# ------------------------
# Processing Record 462|wilmington
# Beginning Data Retrieval
# ------------------------
# Processing Record 463|tiarei
# Beginning Data Retrieval
# ------------------------
# Processing Record 464|ambodifototra
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 465|kirkuk
# Beginning Data Retrieval
# ------------------------
# Processing Record 466|koindu
# Beginning Data Retrieval
# ------------------------
# Processing Record 467|prince rupert
# Beginning Data Retrieval
# ------------------------
# Processing Record 468|vaitupu
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 469|gimli
# Beginning Data Retrieval
# ------------------------
# Processing Record 470|kalevala
# Beginning Data Retrieval
# ------------------------
# Processing Record 471|nikolskoye
# Beginning Data Retrieval
# ------------------------
# Processing Record 472|sal rei
# Beginning Data Retrieval
# ------------------------
# Processing Record 473|bud
# Beginning Data Retrieval
# ------------------------
# Processing Record 474|broome
# Beginning Data Retrieval
# ------------------------
# Processing Record 475|riohacha
# Beginning Data Retrieval
# ------------------------
# Processing Record 476|beloha
# Beginning Data Retrieval
# ------------------------
# Processing Record 477|afrikanda
# Beginning Data Retrieval
# ------------------------
# Processing Record 478|karaul
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 479|matara
# Beginning Data Retrieval
# ------------------------
# Processing Record 480|port shepstone
# Beginning Data Retrieval
# ------------------------
# Processing Record 481|alotau
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 482|jeremoabo
# Beginning Data Retrieval
# ------------------------
# Processing Record 483|pisco
# Beginning Data Retrieval
# ------------------------
# Processing Record 484|oktyabrskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 485|samusu
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 486|texarkana
# Beginning Data Retrieval
# ------------------------
# Processing Record 487|leningradskiy
# Beginning Data Retrieval
# ------------------------
# Processing Record 488|mbanza-ngungu
# Beginning Data Retrieval
# ------------------------
# Processing Record 489|sao joao da barra
# Beginning Data Retrieval
# ------------------------
# Processing Record 490|tromso
# Beginning Data Retrieval
# ------------------------
# Processing Record 491|aflu
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 492|okha
# Beginning Data Retrieval
# ------------------------
# Processing Record 493|raudeberg
# Beginning Data Retrieval
# ------------------------
# Processing Record 494|old road
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 495|leh
# Beginning Data Retrieval
# ------------------------
# Processing Record 496|key west
# Beginning Data Retrieval
# ------------------------
# Processing Record 497|inhambane
# Beginning Data Retrieval
# ------------------------
# Processing Record 498|anajatuba
# Beginning Data Retrieval
# ------------------------
# Processing Record 499|nuuk
# Beginning Data Retrieval
# ------------------------
# Processing Record 500|kindu
# Beginning Data Retrieval
# ------------------------
# Processing Record 501|khorixas
# Beginning Data Retrieval
# ------------------------
# Processing Record 502|san pedro
# Beginning Data Retrieval
# ------------------------
# Processing Record 503|nuevo ideal
# Beginning Data Retrieval
# ------------------------
# Processing Record 504|moose factory
# Beginning Data Retrieval
# ------------------------
# Processing Record 505|ha tinh
# Beginning Data Retrieval
# ------------------------
# Processing Record 506|pizarro
# Beginning Data Retrieval
# ------------------------
# Processing Record 507|oktyabrskoye
# Beginning Data Retrieval
# ------------------------
# Processing Record 508|port keats
# Beginning Data Retrieval
# ------------------------
# Processing Record 509|asau
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 510|husavik
# Beginning Data Retrieval
# ------------------------
# Processing Record 511|korhogo
# Beginning Data Retrieval
# ------------------------
# Processing Record 512|aras
# Beginning Data Retrieval
# ------------------------
# Processing Record 513|quelimane
# Beginning Data Retrieval
# ------------------------
# Processing Record 514|itacare
# Beginning Data Retrieval
# ------------------------
# Processing Record 515|mitu
# Beginning Data Retrieval
# ------------------------
# Processing Record 516|santiago de cao
# Beginning Data Retrieval
# ------------------------
# Processing Record 517|brainerd
# Beginning Data Retrieval
# ------------------------
# Processing Record 518|paciran
# Beginning Data Retrieval
# ------------------------
# Processing Record 519|kavaratti
# Beginning Data Retrieval
# ------------------------
# Processing Record 520|kutum
# Beginning Data Retrieval
# ------------------------
# Processing Record 521|mendi
# Beginning Data Retrieval
# ------------------------
# Processing Record 522|dangriga
# Beginning Data Retrieval
# ------------------------
# Processing Record 523|saint-michel-des-saints
# Beginning Data Retrieval
# ------------------------
# Processing Record 524|andros
# Beginning Data Retrieval
# ------------------------
# Processing Record 525|satitoa
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 526|bacolod
# Beginning Data Retrieval
# ------------------------
# Processing Record 527|balimo
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 528|mason city
# Beginning Data Retrieval
# ------------------------
# Processing Record 529|give
# Beginning Data Retrieval
# ------------------------
# Processing Record 530|hof
# Beginning Data Retrieval
# ------------------------
# Processing Record 531|atambua
# Beginning Data Retrieval
# ------------------------
# Processing Record 532|ternate
# Beginning Data Retrieval
# ------------------------
# Processing Record 533|kuching
# Beginning Data Retrieval
# ------------------------
# Processing Record 534|kargil
# Beginning Data Retrieval
# ------------------------
# Processing Record 535|seybaplaya
# Beginning Data Retrieval
# ------------------------
# Processing Record 536|pacific grove
# Beginning Data Retrieval
# ------------------------
# Processing Record 537|hope
# Beginning Data Retrieval
# ------------------------
# Processing Record 538|siderno
# Beginning Data Retrieval
# ------------------------
# Processing Record 539|okhotsk
# Beginning Data Retrieval
# ------------------------
# Processing Record 540|calamar
# Beginning Data Retrieval
# ------------------------
# Processing Record 541|tilichiki
# Beginning Data Retrieval
# ------------------------
# Processing Record 542|envira
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 543|khandyga
# Beginning Data Retrieval
# ------------------------
# Processing Record 544|black river
# Beginning Data Retrieval
# ------------------------
# Processing Record 545|machali
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 546|coulihaut
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 547|gogrial
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 548|ohara
# Beginning Data Retrieval
# ------------------------
# Processing Record 549|batemans bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 550|kolpashevo
# Beginning Data Retrieval
# ------------------------
# Processing Record 551|ahuimanu
# Beginning Data Retrieval
# ------------------------
# Processing Record 552|mbeya
# Beginning Data Retrieval
# ------------------------
# Processing Record 553|sumbe
# Beginning Data Retrieval
# ------------------------
# Processing Record 554|dubbo
# Beginning Data Retrieval
# ------------------------
# Processing Record 555|camacha
# Beginning Data Retrieval
# ------------------------
# Processing Record 556|port-gentil
# Beginning Data Retrieval
# ------------------------
# Processing Record 557|meyungs
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 558|lucapa
# Beginning Data Retrieval
# ------------------------
# Processing Record 559|torbay
# Beginning Data Retrieval
# ------------------------
# Processing Record 560|jadu
# Beginning Data Retrieval
# ------------------------
# Processing Record 561|daru
# Beginning Data Retrieval
# ------------------------
# Processing Record 562|praia
# Beginning Data Retrieval
# ------------------------
# Processing Record 563|andenes
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 564|baza
# Beginning Data Retrieval
# ------------------------
# Processing Record 565|mayo
# Beginning Data Retrieval
# ------------------------
# Processing Record 566|korla
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 567|batagay-alyta
# Beginning Data Retrieval
# ------------------------
# Processing Record 568|kudat
# Beginning Data Retrieval
# ------------------------
# Processing Record 569|sistranda
# Beginning Data Retrieval
# ------------------------
# Processing Record 570|college
# Beginning Data Retrieval
# ------------------------
# Processing Record 571|krasnyy chikoy
# Beginning Data Retrieval
# ------------------------
# Processing Record 572|olafsvik
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 573|whitehorse
# Beginning Data Retrieval
# ------------------------
# Processing Record 574|avera
# Beginning Data Retrieval
# ------------------------
# Processing Record 575|otradnoye
# Beginning Data Retrieval
# ------------------------
# Processing Record 576|carcassonne
# Beginning Data Retrieval
# ------------------------
# Processing Record 577|omsukchan
# Beginning Data Retrieval
# ------------------------
# Processing Record 578|quesnel
# Beginning Data Retrieval
# ------------------------
# Processing Record 579|shimoda
# Beginning Data Retrieval
# ------------------------
# Processing Record 580|fayaoue
# Beginning Data Retrieval
# ------------------------
# Processing Record 581|nantucket
# Beginning Data Retrieval
# ------------------------
# Processing Record 582|zhigansk
# Beginning Data Retrieval
# ------------------------
# Processing Record 583|bulgan
# Beginning Data Retrieval
# ------------------------
# Processing Record 584|perth
# Beginning Data Retrieval
# ------------------------
# Processing Record 585|rundu
# Beginning Data Retrieval
# ------------------------
# Processing Record 586|englewood
# Beginning Data Retrieval
# ------------------------
# Processing Record 587|palmaner
# Beginning Data Retrieval
# ------------------------
# Processing Record 588|baie du tombeau
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 589|abu dhabi
# Beginning Data Retrieval
# ------------------------
# Processing Record 590|malayal
# Beginning Data Retrieval
# ------------------------
# Processing Record 591|namibe
# Beginning Data Retrieval
# ------------------------
# Processing Record 592|tanggul
# Beginning Data Retrieval
# ------------------------
# Processing Record 593|byron bay
# Beginning Data Retrieval
# ------------------------
# Processing Record 594|hvammstangi
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 595|tashtagol
# Beginning Data Retrieval
# ------------------------
# Processing Record 596|yeehaw junction
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 597|ibresi
# Beginning Data Retrieval
# ------------------------
# Processing Record 598|cangzhou
# Beginning Data Retrieval
# ------------------------
# Processing Record 599|huanren
# Beginning Data Retrieval
# ------------------------
# Processing Record 600|taywarah
# Beginning Data Retrieval
# ------------------------
# Processing Record 601|tandalti
# Beginning Data Retrieval
# ------------------------
# Processing Record 602|san quintin
# Beginning Data Retrieval
# ------------------------
# Processing Record 603|kushima
# Beginning Data Retrieval
# ------------------------
# Processing Record 604|bathsheba
# Beginning Data Retrieval
# ------------------------
# Processing Record 605|port washington
# Beginning Data Retrieval
# ------------------------
# Processing Record 606|skiros
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 607|tabiauea
# City has been obiliterated by aliens. Skipping...
# Beginning Data Retrieval
# ------------------------
# Processing Record 608|ogaminana
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_info_df = pd.DataFrame(city_info)

cloudiness = city_info_df["Cloudiness"]
humidity = city_info_df["Humidity"]
lat = city_info_df["Lat"]
lng = city_info_df["Lng"]
max_temp = city_info_df["Max Temp"]
wind_speed = city_info_df["Wind Speed"]




# Show Record Count
city_info_df.count()
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %%
city_info_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       iqaluit          20      CA  1546491600        74  63.75  -68.52
# 1        hobart           0      AU  1546493400        42 -42.88  147.33
# 2   port alfred          20      ZA  1546495706        81 -33.59   26.89
# 3  richards bay         100      ZA  1546495975       100 -28.77   32.06
# 4  punta arenas          90      CL  1546491600        93 -53.16  -70.91
#
#    Max Temp  Wind Speed
# 0    241.15        1.00
# 1    301.15        6.20
# 2    293.13        6.76
# 3    292.53        3.56
# 4    279.15        5.10

# %%
city_info_df.to_csv("city-weather-data.csv", index=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat,max_temp,label="Cities")
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat,humidity,label="Cities")
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat,cloudiness,label="Cities")
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat,wind_speed,label="Cities")
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("Fig4.png")
plt.show()
